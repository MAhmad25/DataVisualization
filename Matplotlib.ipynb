# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x=np.linspace(0,5,3)
y=x**2
print(x,y)
# Out:
# [0.  2.5 5. ] [ 0.    6.25 25.  ]

# %% [markdown]
# <h3>Displaying Linear Plot</h3>

# %%
plt.plot(x,y)
plt.title("Linear Distribution")
plt.xlabel("X Values")
plt.ylabel("Y Values")
# Out:
# Text(0, 0.5, 'Y Values')

# %% [markdown]
# <h3>Subplot</h3>

# %%
plt.subplot(2,2,1)
plt.plot(x,y)
plt.subplot(2,2,2)
plt.plot(y,x)
plt.subplot(2,2,3)
plt.subplot(2,2,4)
# Out:
# <Axes: >

# %% [markdown]
# <h3>Object Oriented way</h3>

# %%
fig=plt.figure()
axis1=fig.add_axes([0,0,1,1])
axis1.plot(x,y)
axis1=fig.add_axes([0.3,0.6,.3,.3])
axis1.plot(y,x)

# %% [markdown]
# <h3>Types of Plot</h3>

# %%
plt.hist(y)
# Out:
# (array([1., 0., 1., 0., 0., 0., 0., 0., 0., 1.]),
#  array([ 0. ,  2.5,  5. ,  7.5, 10. , 12.5, 15. , 17.5, 20. , 22.5, 25. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(x,y)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x204d3b35450>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x204d3b356d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x204d3b35310>],
#  'medians': [<matplotlib.lines.Line2D at 0x204d3b35950>],
#  'fliers': [<matplotlib.lines.Line2D at 0x204d3b35a90>],
#  'means': []}

# %% [markdown]
# <h3>Image Processing</h3>

# %%
import matplotlib.image as mpimg
img=mpimg.imread("pic2.png")

# %%
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(4087.5), np.float64(2298.5), np.float64(-0.5))

# %%
crop_img=img[50:2000,100:600]
plt.imshow(crop_img)

# %%
plt.plot(x,y,color="red")
